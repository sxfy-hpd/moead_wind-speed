# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
labels = ('case1', 'case2', 'case3', 'case4', 'case5','case6','case7','case8')
y1 = (0.9400,0.9500,0.9800,0.9550,0.9100,0.9500,0.9850,0.9750)
y2 = (0.9016,0.9040,0.9370,0.8960,0.8854,0.9167,0.9210,0.8960)
y3 = (0.9344,0.9236,0.91354,0.9236,0.8725,0.9165,0.9472,0.9653)
y4 = (0.8865,0.9084,0.9662,0.9267,0.876,0.945,0.935,0.9384)
y5 = (0.8889,0.916667,0.958333,0.9168,0.893,0.9166,0.9045,0.9236)
y6 = (0.91,0.867,0.9489,0.9266,0.8654,0.8864,0.8902,0.8883)

x = np.arange(len(labels))  # the label locations
width = 0.13  # the width of the bars

fig, ax = plt.subplots(figsize=(5.5, 4.5), layout='constrained')
plt.ylim((0.85,1))
plt.yticks(fontproperties = 'Times New Roman', size = 10)
plt.xticks(fontproperties = 'Times New Roman', size = 10)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('PICP',fontdict={'family' : 'Times New Roman', 'size'   : 12})
plt.axhline(y=0.90, color="grey", linestyle="--")

ax.bar(x,y1,width=width, alpha=0.4, label="proposed")
ax.bar(x+width,y2,width=width, alpha=0.4,label="Wang's Model")
ax.bar(x+width*2,y3,width=width, alpha=0.4,label="Li's Model")
ax.bar(x+width*3,y4,width=width, alpha=0.4,label="Tang's Model")
ax.bar(x+width*4,y5,width=width, alpha=0.4,label="Liu's Model")
ax.bar(x+width*5,y6,width=width, alpha=0.4,label="Xie's Model")
ax.set_xticks(x + width*2 + width/2, labels)
ax.grid(axis="y",linestyle='--',alpha=0.4)
ax.legend(bbox_to_anchor=(0.5,1.15),loc=9,ncol=3)
fig.tight_layout()
plt.savefig('PICP.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_632/1825335588.py:29: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()

# %%
labels = ('case1', 'case2', 'case3', 'case4', 'case5','case6','case7','case8')
y1 = (0.1330,0.1308,0.1126,0.1153,0.1426,0.2255,0.1599,0.1586)
y2 = (0.2140,0.2370,0.2650,0.1820,0.1654,0.2640,0.1970,0.1664)
y3 = (0.2139,0.2873,0.2452,0.2873,0.2397,0.2360,0.2359,0.2156)
y4 = (0.2130,0.2914,0.3039,0.2246,0.2130,0.2570,0.2897,0.2368)
y5 = (0.2958,0.3324,0.4203,0.3260,0.2860,0.3160,0.2864,0.3185)
y6 = (0.2570,0.2260,0.3156,0.2246,0.2420,0.1946,0.2407,0.2564)

x = np.arange(len(labels))  # the label locations
width = 0.13  # the width of the bars

fig, ax = plt.subplots(figsize=(5.5, 4.5), layout='constrained')
plt.ylim((0.1,0.45))
plt.yticks(fontproperties = 'Times New Roman', size = 10)
plt.xticks(fontproperties = 'Times New Roman', size = 10)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('PINRW',fontdict={'family' : 'Times New Roman', 'size'   : 12})


ax.bar(x,y1,width=width, alpha=0.4, label="proposed")
ax.bar(x+width,y2,width=width, alpha=0.4,label="Wang's Model")
ax.bar(x+width*2,y3,width=width, alpha=0.4,label="Li's Model")
ax.bar(x+width*3,y4,width=width, alpha=0.4,label="Tang's Model")
ax.bar(x+width*4,y5,width=width, alpha=0.4,label="Liu's Model")
ax.bar(x+width*5,y6,width=width, alpha=0.4,label="Xie's Model")
ax.set_xticks(x + width*2 + width/2, labels)
ax.grid(axis="y",linestyle='--',alpha=0.4)
ax.legend(bbox_to_anchor=(0.5,1.15),loc=9,ncol=3)
fig.tight_layout()
plt.savefig('PINRW.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_632/3344151606.py:29: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()

# %%
labels = ('case1', 'case2', 'case3', 'case4', 'case5','case6','case7','case8')
y1 = (1.7982,1.7787,2.1713,1.6916,1.8557,2.3530,1.9591,1.9515)
y2 = (2.2840,2.4220,2.5900,4.3134,4.4726,2.5840,2.1820,4.1204)
y3 = (2.2834,2.7238,2.4712,2.7238,6.1213,2.4160,2.4154,2.2936)
y4 = (5.0673,2.7484,2.8234,2.3476,5.5431,2.5420,2.7382,2.4208)
y5 = (6.0528,2.9944,3.5218,2.9560,5.7327,2.8960,2.7184,2.9110)
y6 = (2.5420,6.2210,2.8936,2.3476,6.5722,4.8257,5.2754,5.5638)


x = np.arange(len(labels))  # the label locations
width = 0.13  # the width of the bars

fig, ax = plt.subplots(figsize=(5.5, 4.5), layout='constrained')
plt.ylim((1.5,6.5))
plt.yticks(fontproperties = 'Times New Roman', size = 10)
plt.xticks(fontproperties = 'Times New Roman', size = 10)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('CWC',fontdict={'family' : 'Times New Roman', 'size'   : 12})


ax.bar(x,y1,width=width, alpha=0.4, label="proposed")
ax.bar(x+width,y2,width=width, alpha=0.4,label="Wang's Model")
ax.bar(x+width*2,y3,width=width, alpha=0.4,label="Li's Model")
ax.bar(x+width*3,y4,width=width, alpha=0.4,label="Tang's Model")
ax.bar(x+width*4,y5,width=width, alpha=0.4,label="Liu's Model")
ax.bar(x+width*5,y6,width=width, alpha=0.4,label="Xie's Model")
ax.set_xticks(x + width*2 + width/2, labels)
ax.grid(axis="y",linestyle='--',alpha=0.4)
ax.legend(bbox_to_anchor=(0.5,1.15),loc=9,ncol=3)
fig.tight_layout()
plt.savefig('CWC.png',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_632/3856469649.py:30: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()
